# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾

# %% [markdown]
# ## ANS. 服飾相關
#
# 參考平台：https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6627067&str_category_code=1318900058&mdiv=1318900058-bt_9_002_01&ctype=B&Area=DgrpCategory
#
# ![image.png](attachment:image.png)
#
# #### 相關資訊
#
# 品牌名稱:KVOLL
#
# 適用對象:女生
#
# 風格:性感、美式休閒、韓風、舒適休閒、時尚個性、個性、歐美風、渡假
#
# 領口:圓領
#
# ### 資料來源
# 網路店家自行分類或定義
#
# ### 目標
# 未來針對不同服裝，可以自行判別出其品牌、適用對象、風格與領口...等，使用電腦自行標註
#
# ### 評估指標
# 利用圖片找出相關特徵、或輸入一堆已知圖放入模型訓練
